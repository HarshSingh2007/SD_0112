# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict1={'a':"HARSH",'b':"Kumar",'c':"Singh"}
keys=[]
values=[]
for key,value in dict1.items():
    keys.append(key)
    values.append(value)
print(keys)
print(values)
# Out:
# ['a', 'b', 'c']
# ['HARSH', 'Kumar', 'Singh']

# %%
l=[2,3,4,5]
sum=0
for i in l:
  sum+=i
print(sum)
# Out:
# 14

# %%
l1=[2,55,8,8,58,57,63,51,12]
l1[0:8:2]
sum=0
for i in l1:
  sum+=i
print(sum)
# Out:
# 314

# %%
l2=[5,6,7,8,9,10]
l2[0:5]
sum_odd=0
sum_even=0
for n in l2:
    if n%2==0:
       sum_even+=n
    else:
       sum_odd+=n


print(sum_even)
print(sum_odd)
# Out:
# 24
# 21
