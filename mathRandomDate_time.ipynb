# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/mathRandomDate_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
num=25
print(math.sqrt(num))
# Out:
# 5.0

# %%
print(math.pow(num,3))
# Out:
# 15625.0

# %%
print(math.factorial(num))
# Out:
# 15511210043330985984000000

# %%
print(math.ceil(4.3))
# Out:
# 5

# %%
print(math.floor(4.5))
# Out:
# 4

# %%
print(abs(-5.56))
# Out:
# 5.56

# %%
print(math.gcd(45,81))
# Out:
# 9

# %%
print(math.lcm(3,6,9,12))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
import math
print(math.cos(math.radians(0)))
# Out:
# 1.0

# %%
import math
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(100)) #default base is "e"
# Out:
# 4.605170185988092

# %%
import random
print(random.randint(1,6))
# Out:
# 2

# %%
import random

# %%
print(random.random())   #random value bw zero and one
# Out:
# 0.5004136938770204

# %%
print(random.randrange(1,100))
# Out:
# 23

# %%
import random
fruits=["apple","banana","mango","orange"]
print(random.choice(fruits))
# Out:
# orange

# %%
numbers=[1,2,3,4,5]
random.shuffle(numbers)
print(numbers)
# Out:
# [3, 1, 5, 2, 4]

# %%
print(random.uniform(1,10))  #returns random float values
# Out:
# 4.05930660206543

# %%
print(random.choice([True,False]))
# Out:
# True

# %%
otp=random.randint(1000,9999)
print("OTP="+str(otp))
# Out:
# OTP=5420

# %%
#date-time

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:28:11.866826

# %%
print(datetime.datetime.now().time())
# Out:
# 06:30:58.622062

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().date())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().day)
# Out:
# 20

# %%
print(datetime.datetime.now().month)
# Out:
# 7

# %%
print(datetime.datetime.now().minute)
# Out:
# 37

# %%
print(datetime.datetime.now().second)
# Out:
# 22

# %%
#custom

# %%
#custom
import datetime

d=datetime.date(2006,3,28)
print(d)
# Out:
# 2006-03-28

# %%
date1=datetime.date(2006,3,28)
date2=datetime.date(2011,7,18)
print(date2-date1)
# Out:
# 1938 days, 0:00:00

# %%
today=datetime.datetime.now()
print(today.strftime("%D-%M-%Y"))
# Out:
# 07/20/26-49-2026

# %%
today=datetime.datetime.now()
print(today.strftime("%A"))
# Out:
# Monday

# %%
today=datetime.datetime.now()
print(today.strftime("%B"))
# Out:
# July
