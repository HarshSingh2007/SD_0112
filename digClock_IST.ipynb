# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/digClock_IST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import ZoneInfo
while True:
  clear_output(wait=True)
  ist_time=datetime.now(ZoneInfo("Asia/Kolkata"))
  print("      DIGITAL CLOCK")
  print("Date:",ist_time.strftime("%d/%m/%Y"))
  print("Day:",ist_time.strftime("%A"))
  print("Time:",ist_time.strftime("%I:%M:%S %p"))
  print("Zone:","Indian Standard Time (IST)")

  time.sleep(1)
