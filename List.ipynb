# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums=[1,2,3,4]

# %%
nums[0]
# Out:
# 1

# %%
nums[1]
# Out:
# 2

# %%
nums[2]
# Out:
# 3

# %%
nums[3]
# Out:
# 4

# %%
nums[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_520/2255194133.py in <cell line: 0>()
# ----> 1 nums[4]
#
# IndexError: list index out of range

# %%
type(num)
# Out:
# list

# %%
newNums=["Harsh",28,3,2007,"Lucknow",True,0.28,2+7j,False]

# %%
newNums[0:7:2]
# Out:
# ['Harsh', 3, 'Lucknow', 0.28]

# %%
newNums[7].real
# Out:
# 0

# %%
newNums[0:7:2]
# Out:
# ['Harsh', 3, 'Lucknow', 0.28]

# %%
newNums[0:7:4]
# Out:
# ['Harsh', 'Lucknow']

# %%
newNums[-1]
# Out:
# False

# %%
newNums[::-1]
# Out:
# [False, 0.28, True, 'Lucknow', 2007, 3, 28, 'Harsh']

# %%
newNums[-1:-5:-2]
# Out:
# [False, True]

# %%
l=[1,345,45,"sudh",True,(5+7j),345.56]

# %%
l[0:7:6]
# Out:
# [1, 345.56]

# %%
l.append("new element 1")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.56,
#  'new element 1',
#  'new element 1',
#  'new element 1',
#  'new element 1',
#  'new element 1']

# %%
l.pop()
# Out:
# 'new element 1'

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.56,
#  'new element 1',
#  'new element 1',
#  'new element 1']

# %%
l.pop(6)
# Out:
# 'new element 1'

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 'new element 1', 'new element 1']

# %%
s="my name is Harsh Kumar Singh"

# %%
l.append(s)

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2422/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  'new element 1',
#  'new element 1',
#  'my name is Harsh Kumar Singh',
#  'my name is Harsh Kumar Singh']

# %%
list(s)+l
# Out:
# ['m',
#  'y',
#  ' ',
#  'n',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'H',
#  'a',
#  'r',
#  's',
#  'h',
#  ' ',
#  'K',
#  'u',
#  'm',
#  'a',
#  'r',
#  ' ',
#  'S',
#  'i',
#  'n',
#  'g',
#  'h',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  'new element 1',
#  'new element 1',
#  'my name is Harsh Kumar Singh',
#  'my name is Harsh Kumar Singh']

# %%
li=[1,345,45,"harsh",True,(5+7j),345.456]
