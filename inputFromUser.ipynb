# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/inputFromUser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("enter your name")
# Out:
# enter your nameHarsh

# %%
name
# Out:
# 'Harsh'

# %%
age=int(input("enter your age:"))
# Out:
# enter your age:19

# %%
age
# Out:
# 19

# %%
print("Name:", name)
print("age:", age)
# Out:
# Name: Harsh
# age: 19

# %%
x="10"
y=int(x)
print(type(y))
print(y)
# Out:
# <class 'int'>
# 10

# %%
x="3.14"
y=float(x)
print(type(y))
print(y)
# Out:
# <class 'float'>
# 3.14

# %%
x=25
y=str(x)
print(type(y))
# Out:
# <class 'str'>

# %%
x=(1,2.3)
y=list(x)
print(type(y))
print(y)
# Out:
# <class 'list'>
# [1, 2.3]

# %%
x=[1,2,3]
y=tuple(x)
print(type(y))
print(y)
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %%
x=[1,2,3]
y=set(x)
print(type(y))
print(y)
# Out:
# <class 'set'>
# {1, 2, 3}
