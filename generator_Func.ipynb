# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/generator_Func.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fibo series


def fibo(n):
  a,b=0,1
  for i in range(n):
      yield a

      a,b=b , a+b

for i in fibo(5):

    print(i)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
next(fibo(5))
# Out:
# 0

# %%
def fib2(n):
  a,b=0,1
  while True:
   yield a
   a,b=b,a+b

fib2(5)
# Out:
# <generator object fib2 at 0x7ec93e0125a0>

# %%
s="Harsh"
for i in s:
  print(i)
# Out:
# H
# a
# r
# s
# h

# %%
next(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1894/1977886155.py in <cell line: 0>()
# ----> 1 next(s)
#
# TypeError: 'str' object is not an iterator

# %%
s1="harsh"

# %%
s2=iter(s1)

# %%
next(s2)
# Out:
# 'a'

# %%
next(s2)
# Out:
# 's'

# %%
next(45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1894/2317411141.py in <cell line: 0>()
# ----> 1 next(45)
#
# TypeError: 'int' object is not an iterator

# %%
b=45

# %%
def count_test(n):
  count=1
  while count<=n:
    yield count
    count+=1

# %%
count_test(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1318/566714738.py in <cell line: 0>()
# ----> 1 count_test(3)
#
# NameError: name 'count_test' is not defined

# %%
def count_test(n):
  count=1
  while count<=n:
    yield count
    count=count+1
for a in count_test(3)  :

    print(a)
