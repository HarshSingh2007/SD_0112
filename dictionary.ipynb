# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={'key': "sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2={'name':"Harsh Singh",'email':"email.com",'number':3356}

# %%
d2
# Out:
# {'name': 'Harsh Singh', 'email': 'email.com', 'number': 3356}

# %%
d3={234:'sudh','_wer':'kumar',True:2434}

# %%
d3
# Out:
# {234: 'sudh', '_wer': 'kumar', True: 2434}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[1]
# Out:
# 2434
