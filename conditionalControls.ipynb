# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshSingh2007/SD_0112/blob/main/conditionalControls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
if x >5 :
  print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x=3
if x%2==0:
  print("even number")
else:
  print("odd number")
# Out:
# odd number

# %%
name=str(input("Enter your name:"+" "))
course=str(input("Enter your course:"+" "))
branch=str(input("Enter your branch:"+" "))
rollNumber=int(input("Enter your Roll number:"+ " "))
print("-----Please enter the marks for following subjects out of 100-----\n")
m1=int(input("Enter marks of Python:"+" "))
m2=int(input("Enter marks of COA:"+" "))
m3=int(input("Enter marks of Maths-4:"+" "))
m4=int(input("Enter marks of DSTL:"+ "\n"))
m5=int(input("Enter the marks of Universal Values:"+" "))
sum=m1+m2+m3+m4+m5
print("-----Total marks obtained is------"+" "+str(sum))
per=sum/5
print("-----Percentage is=----"+" "  +str(per))
# Out:
# Enter your name: Harsh Kumar Singh
# Enter your course: B.Tech
# Enter your branch: CSE
# Enter your Roll number: 2501220100112
# -----Please enter the marks for following subjects out of 100-----
#
# Enter marks of Python: 89
# Enter marks of COA: 87
# Enter marks of Maths-4: 54
# Enter marks of DSTL:
# 65
# Enter the marks of Universal Values: 84
# -----Total marks obtained is------ 379
# -----Percentage is=---- 75.8

# %%
name=str(input("Enter your name:"+" "))
course=str(input("Enter your course:"+" "))
branch=str(input("Enter your branch:"+" "))
rollNumber=int(input("Enter your Roll number:"+" "))
print("-----Please enter the marks for following subjects out of 100-----\n")
m1=int(input("Enter marks of Python:"+" "))
m2=int(input("Enter marks of COA:"+" "))
m3=int(input("Enter marks of Maths-4:"+" "))
m4=int(input("Enter marks of DSTL:"+" "))
m5=int(input("Enter marks of Universal Values:"+" "))
sum=m1+m2+m3+m4+m5
print("-----Total marks obtained is------"+" "+str(sum))
per=sum/5
print("-----Percentage is=----"+" "  +str(per))

if per>=90:
  print("-----Grade A-----")
elif per>=80:
  print("-----Grade B------")
elif per>=70:
  print("-----Grade C-----")
elif per>=60:
  print("-----Grade D------")
# Out:
# Enter your name: Harsh Kumar Singh
# Enter your course: B.Tech
# Enter your branch: CSE
# Enter your Roll number: 2501220100112
# -----Please enter the marks for following subjects out of 100-----
#
# Enter marks of Python: 89
# Enter marks of COA: 89
# Enter marks of Maths-4: 56
# Enter marks of DSTL: 54
# Enter marks of Universal Values: 84
# -----Total marks obtained is------ 372
# -----Percentage is=---- 74.4
# -----Grade C-----
